# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
import matplotlib.pyplot as plt

# %%
#Using Uniform 
df = pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])
df.dropna(inplace = True)
x = df.iloc[:,1:]
y = df["Survived"]

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
Kbin_age = KBinsDiscretizer(n_bins=5,encode='ordinal',strategy='quantile')
Kbin_fare = KBinsDiscretizer(n_bins=5,encode='ordinal',strategy='quantile')

trf = ColumnTransformer([
    ('first',Kbin_age,[0]),
    ('second',Kbin_fare,[1])
])

X_train_trf = trf.fit_transform(X_train)
output = pd.DataFrame({
    'age':X_train['Age'],
    'age_trf':X_train_trf[:,0],
    'fare':X_train['Fare'],
    'fare_trf':X_train_trf[:,1]
})
output
# Out:
#       age  age_trf      fare  fare_trf
# 328  31.0      2.0   20.5250       2.0
# 73   26.0      2.0   14.4542       2.0
# 253  30.0      2.0   16.1000       2.0
# 719  33.0      3.0    7.7750       0.0
# 666  25.0      2.0   13.0000       2.0
# ..    ...      ...       ...       ...
# 92   46.0      4.0   61.1750       4.0
# 134  25.0      2.0   13.0000       2.0
# 337  41.0      3.0  134.5000       4.0
# 548  33.0      3.0   20.5250       2.0
# 130  33.0      3.0    7.8958       1.0
#
# [571 rows x 4 columns]

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.hist(output['age'])
plt.title("Before")
plt.subplot(122)
plt.hist(output['age_trf'],color='red')
plt.title("After")
plt.show()

plt.figure(figsize=(14,4))
plt.subplot(121)
plt.hist(output['fare'])
plt.title("Before")
plt.subplot(122)
plt.hist(output['fare_trf'],color='red')
plt.title("Fare")
plt.show()

# %%
#Using Uniform 
df = pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])
df.dropna(inplace = True)
x = df.iloc[:,1:]
y = df["Survived"]

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
Kbin_age = KBinsDiscretizer(n_bins=7,encode='ordinal',strategy='uniform')
Kbin_fare = KBinsDiscretizer(n_bins=7,encode='ordinal',strategy='uniform')

trf = ColumnTransformer([
    ('first',Kbin_age,[0]),
    ('second',Kbin_fare,[1])
])

X_train_trf = trf.fit_transform(X_train)
output = pd.DataFrame({
    'age':X_train['Age'],
    'age_trf':X_train_trf[:,0],
    'fare':X_train['Fare'],
    'fare_trf':X_train_trf[:,1]
})

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.hist(output['age'])
plt.title("Before")
plt.subplot(122)
plt.hist(output['age_trf'],color='red')
plt.title("After")
plt.show()

plt.figure(figsize=(14,4))
plt.subplot(121)
plt.hist(output['fare'])
plt.title("Before")
plt.subplot(122)
plt.hist(output['fare_trf'],color='red')
plt.title("Fare")
plt.show()

# %%
#using Kmeans
#Using Uniform 
df = pd.read_csv('train.csv',usecols=['Age','Fare','Survived'])
df.dropna(inplace = True)
x = df.iloc[:,1:]
y = df["Survived"]

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)
Kbin_age = KBinsDiscretizer(n_bins=5,encode='ordinal',strategy='kmeans')
Kbin_fare = KBinsDiscretizer(n_bins=5,encode='ordinal',strategy='kmeans')

trf = ColumnTransformer([
    ('first',Kbin_age,[0]),
    ('second',Kbin_fare,[1])
])

X_train_trf = trf.fit_transform(X_train)
output = pd.DataFrame({
    'age':X_train['Age'],
    'age_trf':X_train_trf[:,0],
    'fare':X_train['Fare'],
    'fare_trf':X_train_trf[:,1]
})
# Out:
# C:\Users\skars\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\skars\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.hist(output['age'])
plt.title("Before Age")
plt.subplot(122)
plt.hist(output['age_trf'],color='red')
plt.title("After Age")
plt.show()

plt.figure(figsize=(14,4))
plt.subplot(121)
plt.hist(output['fare'])
plt.title("Before Fare")
plt.subplot(122)
plt.hist(output['fare_trf'],color='red')
plt.title("After Fare")
plt.show()
