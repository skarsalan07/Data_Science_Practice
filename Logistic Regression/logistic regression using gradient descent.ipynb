# %%
from sklearn.datasets import make_classification
import numpy as np
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
import matplotlib.pyplot as plt 

plt.scatter(X[:,0],X[:,1],c=y)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
print(lr.coef_ ,"<< this are the coef")
# Out:
# [[3.50204668 0.02749943]] << this are the coef

# %%
print(lr.intercept_,"<< this are the intercept")
# Out:
# [2.25256402] << this are the intercept

# %%
def logistic_regression(X,y):
    X = np.insert(X,0,1,axis=1)
    weights = np.ones(X.shape[1])
    lr = 0.01
    for i in range(5000):
        y_hat = Sigmoid(np.dot(X,weights))
        weights = weights + lr*(np.dot((y-y_hat),X)/X.shape[0])

    return weights[0],weights[1:]
intercep,coef = logistic_regression(X,y)

# %%
def Sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
print(intercep,coef)
# Out:
# 2.025632959380709 [3.59596114 0.04434871]
