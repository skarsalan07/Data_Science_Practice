# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')
sns.boxplot(df["cgpa"])
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (200, 2)

# %%
df.sample(5)
# Out:
#      cgpa  package
# 91   6.22     2.14
# 187  6.26     2.44
# 160  7.13     2.93
# 92   7.90     4.00
# 116  9.04     3.33

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['cgpa'])

plt.show()
# Out:
# C:\Users\skars\AppData\Local\Temp\ipykernel_10628\3716515190.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# C:\Users\skars\AppData\Local\Temp\ipykernel_10628\3716515190.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])

# %%
df['cgpa'].skew()
# Out:
# 0.029654878985542518

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 6.990500000000001
# Std value of cgpa 1.0694086798895523
# Min value of cgpa 4.26
# Max value of cgpa 9.58

# %%
# Finding the boundary values
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 10.198726039668658
# Lowest allowed 3.7822739603313438

# %%
# Finding the outliers
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  package
# 12   8.94     3.65
# 40   9.38     4.02
# 44   5.09     1.86
# 49   8.87     4.62
# 50   9.58     4.43
# 51   9.26     3.79
# 63   9.16     4.25
# 77   8.99     4.60
# 84   4.26     1.53
# 85   4.79     1.48
# 88   4.73     1.48
# 116  9.04     3.33
# 123  5.10     2.30
# 143  4.85     1.54
# 163  8.93     3.91
# 164  9.06     3.82
# 169  9.31     4.37
# 193  4.57     1.94

# %% [markdown]
# ## Trimming

# %%
# Trimming

new_df = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]
new_df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [181 rows x 2 columns]

# %%
# Approach 2

# Calculating the Zscore

df['cgpa_zscore'] = (df['cgpa'] - df['cgpa'].mean())/df['cgpa'].std()
# Out:
# 0     -0.093977
# 1     -1.749097
# 2      0.775662
# 3      0.401624
# 4     -0.047222
#          ...
# 195   -0.056573
# 196   -1.029073
# 197    0.205254
# 198    0.597994
# 199   -0.720492
# Name: cgpa_zscore, Length: 200, dtype: float64

# %%
df.head()
# Out:
#    cgpa  package  cgpa_zscore
# 0  6.89     3.26    -0.093977
# 1  5.12     1.98    -1.749097
# 2  7.82     3.25     0.775662
# 3  7.42     3.67     0.401624
# 4  6.94     3.57    -0.047222

# %%
df[df['cgpa_zscore'] > 3]
# Out:
# Empty DataFrame
# Columns: [cgpa, package, cgpa_zscore]
# Index: []

# %%
df[df['cgpa_zscore'] < -3]
# Out:
# Empty DataFrame
# Columns: [cgpa, package, cgpa_zscore]
# Index: []

# %%
df[(df['cgpa_zscore'] > 3) | (df['cgpa_zscore'] < -3)]
# Out:
# Empty DataFrame
# Columns: [cgpa, package, cgpa_zscore]
# Index: []

# %%
# Trimming 
new_df = df[(df['cgpa_zscore'] < 3) & (df['cgpa_zscore'] > -3)]

# %%
new_df
# Out:
#      cgpa  package  cgpa_zscore
# 0    6.89     3.26    -0.093977
# 1    5.12     1.98    -1.749097
# 2    7.82     3.25     0.775662
# 3    7.42     3.67     0.401624
# 4    6.94     3.57    -0.047222
# ..    ...      ...          ...
# 195  6.93     2.46    -0.056573
# 196  5.89     2.57    -1.029073
# 197  7.21     3.24     0.205254
# 198  7.63     3.96     0.597994
# 199  6.22     2.33    -0.720492
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Capping

# %%
upper_limit = df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit = df['cgpa'].mean() - 3*df['cgpa'].std()

# %%
lower_limit
# Out:
# 3.7822739603313438

# %%
df['cgpa'] = np.where(
    df['cgpa']>upper_limit,
    upper_limit,
    np.where(
        df['cgpa']<lower_limit,
        lower_limit,
        df['cgpa']
    )
)

# %%
df.shape
# Out:
# (200, 3)

# %%
df['cgpa'].describe()
# Out:
# count    200.000000
# mean       6.990500
# std        1.069409
# min        4.260000
# 25%        6.190000
# 50%        6.965000
# 75%        7.737500
# max        9.580000
# Name: cgpa, dtype: float64
